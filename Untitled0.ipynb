# %% [markdown]
# <a href="https://colab.research.google.com/github/taayshanilofar-beep/ict-assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT

# %%
a = int(input("enter the price of first item:"))
b = int(input("enter the price of second item:"))
c = int(input("number of quantity of first item:"))
d = int(input("number of quantity of second item:"))
print("total bill amount is:",a*c+b*d)
# Out:
# enter the price of first item:45
# enter the price of second item:30
# number of quantity of first item:3
# number of quantity of second item:2
# total bill amount is: 195

# %%
c= float(input("enter the temperature in celsius:"))
f=(c*9/5)+32
print(f)
# Out:
# enter the temperature in celsius:30
# 86.0

# %%
s= float(input("enter the basic salary:"))
hra=0.20
da=0.10
hrasalary=s*hra
dasalary=s*da
print("netsalary is",s+hrasalary+dasalary)
# Out:
# enter the basic salary:20000
# netsalary is 26000.0

# %%
principal=float(("enter the principal amount:"))
rate_of_interest=float(("enter the rate of interest:"))
time=float(("enter the time :"))
simple_interest=(principal*rate of interest*time)/100
print("the simple interest is:",simple_interest)
# Out:
#   File "/tmp/ipython-input-1449295507.py", line 4
#     simple_interest=((principal*rate of interest*time)/100
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
total_minutes = int(input('enter the total minutes:'))
hours = total_minutes //60
minutes = total_minutes %60
print(f'{hours}hours and{minutes}minutes,')
# Out:
# enter the total minutes:130
# 2hours and10minutes,

# %%
weight  = float(input('Enter the weight:'))
height = float(input('Enter the height:'))
BMI = weight / height**2
print(f"BMI = {bmi:2f}")
# Out:
# Enter the weight:60
# Enter the height:1.65
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1867764333.py in <cell line: 0>()
#       2 height = float(input('Enter the height:'))
#       3 BMI = weight / height**2
# ----> 4 print(f"BMI = {bmi:2f}")
#
# NameError: name 'bmi' is not defined
